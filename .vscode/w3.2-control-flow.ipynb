# %%
# conditional logic

# ==, >, >=, <, <=, !=
 # python reads as, if left is = to right : true
 
a = 7
b = 10
print(a==b)
# Out:
# False

# %%
num_chances = 2
our_chance = input ('Please enter a number: ')
our_chance = int(our_chance)
print(f"User chose {our_chance}")
print(our_chance > num_chances)
# Out:
# User chose 3
# True

# %%
# not equal

a = False

print(a!=True)
# Out:
# True

# %%
# Truthy and Falsy

a = 7
print(bool(a))
# Out:
# True

# %%
# Falsy
# 0, 0.0, False, None, [], {},(), ""
my_list = ""
print(bool(my_list))
# Out:
# True

# %%
# if statements
condition = ''
if condition:
    pass # does not do anything allows to continue logic without error
    print(f"condition is true")
elif not condition:
    pass
    print("condition is false")
else:
    print('i got to the else statement')
    
print(f'not statement = {not condition}')
# Out:
# condition is false
# not statement = True

# %%
num = input ("please enter a number between 1 and 10 ")
num = int(num)

if num < 3: 
    print(f'num is less than 3: {num}')
elif num > 6:
    print(f"num is greater than 6: {num}")
else: 
    print(f"num is between 3 and 6")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 num = input ("please enter a number between 1 and 10 ")
# ----> 2 num = int(num)
#       4 if num < 3:
#       5     print(f'num is less than 3: {num}')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# let's try to make this better with try except

num = input ("choose a number between 1 and 10")

try: 
    num = int(num)
    
    if num < 3: 
        print(f'num is less than 3: {num}')
    elif num > 6:
        print(f"num is greater than 6: {num}")
    else: 
        print(f"num is between 3 and 6")
except Exception as e:
    print (f"Well that didnt work, try again: {e}")
# Out:
# Well that didnt work, try again: invalid literal for int() with base 10: 'x'

# %%
# Type hinting: str, float, int, bool

# Nested if statements

variable: str = input(f" Please, enter a value")

if variable. isnumeric():
    try: 
        num: float = float(variable)
        if num > 10:
            print("The value is too high, start over")
        else:
            print(f"{num} is a good choice")
    except Exception as e:
        print(f"There was an error: {e}")
elif variable.isalpha():
    print(f" you chose, {variable.upper()}")
else:
    print("Please enter either a number or a letter")
# Out:
# 5.0 is a good choice

# %%
number = input("Choose a number between 1 and 10!")

# and statement
if number. isnumeric():
    try:
        number = int(number)
        if number >= 1 and number <=10:
            print(f"you chose correctly: {number}")
        else:
            print(f"You suck! {number} is not between 1 and 10")
    except Exception as e:
        print(e)
    number = int(number)
else:
    print("please choose a number")
# Out:
# you chose correctly: 9

# %%
# want a nymber not between 1 and 10 or -10 and -1

number = input("please choose a number between -10 and -1 or 1 and 10")

try:
    if not number.isnumeric ():
        raise Exception (f"{number} is not a number buster. Try reading!")
        
    number = int(number)
    if (number < -10 or number > -1) and (number <1 or number > 10):
        raise Exception (f"{number} doesn't meet the rules. Pay attention")
    
    print(f"""
Hooray!!! You made it through: {number} meets the rules. 
Sorry if you chose a negetive number, but '-' is not numeric
""" )
except Exception as e:
    print(f"There was an error {e} ")
# Out:
# Hooray!!! You made it through: 9 meets the rules.
# Sorry if you chose a negetive number, but '-' is not numeric

# %%
from typing import list, dict, set, tuple

# in operator
names: list[str] = ["Nate","Rebecca", "Edwin", "Preston"] # use for or to give options [Str | Int]

choice = input(f" Choose a name from the following {','.join(names)}")
if choice.capitalize() in names:
    print(f" Hooray, {choice} is in names")
else:
    print("You suck! Follow directions")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 from typing import list, dict, set, tuple
#       3 # in operator
#       4 names: list[str] = ["Nate","Rebecca", "Edwin", "Preston"] # use for or to give options [Str | Int]
#
# ImportError: cannot import name 'list' from 'typing' (/opt/anaconda3/envs/python-class/lib/python3.13/typing.py)

# %%
x = 8
y = 12
result= x > 5 and y < 10
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 4
#       2 y = 12
#       3 result = x > 5 and y < 10
# ----> 4 print(results)
#
# NameError: name 'results' is not defined
