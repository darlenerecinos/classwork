# %%
#%conda install statsmodels

import pandas as pd
import scipy.stats as stats
url= "https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/penguins_cleaned.csv"

df=pd.read_csv(url)
df.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7                181
#
#    body_mass_g   sex
# 0         3750  male

# %%
df["species"].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
df["island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df["sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
males = df.loc[df["sex"]=="male", "body_mass_g"]
females = df.loc[df["sex"]=="female", "body_mass_g"]
t,p=stats.ttest_ind(males,females)
print(f"t={t:.4f}, p={p:.4f}")
# Out:
# t=8.5417, p=0.0000

# %%
deg_f=len(males) + len(females) -2
alpha = 0.05
crit_t=stats.t.ppf(1-alpha / 2,deg_f)
crit_t
# Out:
# np.float64(1.9671567996106814)

# %%
males.mean()
# Out:
# np.float64(4545.684523809524)

# %%
females.mean()
# Out:
# np.float64(3862.2727272727275)

# %%
males.mean()-females.mean()
print ("Males are bigger by this many g")
males.mean()-females.mean()
# Out:
# Males are bigger by this many g
# np.float64(683.4117965367964)

# %%
adalie = df.loc[df["species"]=="Adalie", "body_mass_g"]
gentoo= df.loc[df["species"]=="Gentoo", "body_mass_g"]
chinstrap = df.loc[df["species"]=="Chinstrap", "body_mass_g"]

f,p =stats.f_oneway(adalie,gentoo,chinstrap)
print(f"{f:4f}/{p:.4f}")
# Out:
#  nan/nan
# /var/folders/m9/z30nfghs5xs3cndqgmk7rr200000gn/T/ipykernel_2088/1090711321.py:5: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f,p =stats.f_oneway(adalie,gentoo,chinstrap)

# %%
# lets do this faster
cols = df["species"].unique()
samples = [df.loc[df["species"]==var,"body_mass_g"]for var in df["species"].unique()]
f,p = stats.f_oneway(*samples)
print(f"f={f:.4f},p={p:.4f}")
# Out:
# f=341.8949,p=0.0000

# %%
#critical f
dfb = len(df["species"].unique())-1
dfw=len(df["body_mass_g"])-len(df["species"].unique())
alpha=0.05
crit_f = stats.f.ppf(1-alpha,dfb,dfw)

print(f"f={f:4f},threshold={crit_f:.4f}")
# Out:
# f=341.894895,threshold=3.0231

# %%
scipy_tukey = stats.tuckey_hsd(*samples)
print(scipy_tukey)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 scipy_tukey = stats.tuckey_hsd(*samples)
#       2 print(scipy_tukey)
#
# AttributeError: module 'scipy.stats' has no attribute 'tuckey_hsd'

# %%
sm_tukey = pairwise_tukeyhsd(
    endog=df["body_mass_g"] #numeric variable
    groups=df["species"]
    alpha=0.05
)
sm_tukey.summary()
# Out:
#   Cell In[35], line 2
#     endog=df["body_mass_g"] #numeric variable
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
