# %%
#date_of_birth & height in cm
from scipy import stats
heights = df["height_in_cm"]
sk = stats.skew(heights)
kurt = stats.skew(heights, nan_policy = "omit")
kurt = stats.kertosis(heights, nan_policy = "omit")
print(f"skew={sk:.3f}; kurt = {kurt}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #date_of_birth & height in cm
#       2 from scipy import stats
# ----> 3 heights = df["height_in_cm"]
#       4 sk = stats.skew(heights)
#       5 kurt = stats.skew(heights, nan_policy = "omit")
#
# NameError: name 'df' is not defined
