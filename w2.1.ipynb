# %% [markdown]
# # Variables

# %% [markdown]
# ## Simple Variables

# %% [markdown]
# - String (str)
# - integer (int)
# - floats (float)
# - boolean (bool)

# %% [markdown]
# # Methods / Math

# %%
# comments are made with hash tags

# %%
# Strings

# StringInferred capitalization is used for classes
# we do not used stringinferred because of convention

string_inferred = "This is my super awesome string!"
string_declared = str("A declared string!")
string_int = "12345"
string_int2 ="567"

print(string_inferred)
print(type(string_inferred))
print(string_int + string_int2) # concatenation
# Out:
# This is my super awesome string!
# <class 'str'>
# 12345567

# %%
string_inferred
# Out:
# 'This is my super awesome string!'

# %%
# int 

int_inferred = 123
int_declared = int(456)
int_coerced = int("789") # coercion from string to int

print(int_inferred,type(int_inferred))
print(int_declared + int_coerced)
# Out:
# 123 <class 'int'>
# 1245

# %%
# float

float_inferred = 1.0
float_declared = float(2)

print("float_inferred + float_declared = ", float_inferred + float_declared)
print(f"float_inferred:{float_inferred} + float_declared {float_declared} = float_inferred")
# Out:
# float_inferred + float_declared =  3.0
# float_inferred:1.0 + float_declared 2.0 = float_inferred

# %%
print(f"coerce float_inferred to int: {int(9.99999)}")
# Out:
# coerce float_inferred to int: 9

# %%
# boolean

bool_inferred = True
bool_declared = bool(0)

print(bool_inferred)
print(bool_declared)
# Out:
# True
# False

# %% [markdown]
# ## int is a whole # while float is a decimal, string is series of characters in double or single quotations, boolean is t/f
